# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.callbacks import TensorBoard
import pickle
import time
import cv2
import os
import matplotlib.pyplot as plt

# %%
NAME = "covid19-vs-noncovid19-CNN"

x = pickle.load(open("x.pickle","rb"))
y = pickle.load(open("y.pickle","rb"))
testingx = pickle.load(open("testingx.pickle","rb"))
testingy = pickle.load(open("testingy.pickle","rb"))
x = x/225.0
tesingx = testingx/225.0

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Flatten(),
                                   tf.keras.layers.Dense(128, activation=tf.nn.relu),
                                 tf.keras.layers.Dense(2, activation=tf.nn.softmax)])


tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

model.compile(loss='binary_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'],
             )


y = np.array(y)

# %%
model.fit(x, y, epochs=150,validation_split=0.2,callbacks=[tensorboard], validation_data=(testingx,testingy))


model.save('my-CNN.model')
# Out:
# Epoch 1/150
# ...
# 17/17 [==============================] - 0s 14ms/step - loss: 7.6697 - accuracy: 0.5130 - val_loss: 7.6795 - val_accuracy: 0.6250
# Epoch 2/150
# 17/17 [==============================] - 0s 11ms/step - loss: 7.6697 - accuracy: 0.5130 - val_loss: 7.6795 - val_accuracy: 0.6250
# Epoch 3/150
# 17/17 [==============================] - 0s 10ms/step - loss: 7.6697 - accuracy: 0.5130 - val_loss: 7.6795 - val_accuracy: 0.6250
# Epoch 4/150
# 17/17 [==============================] - 0s 10ms/step - loss: 7.6697 - accuracy: 0.5130 - val_loss: 7.6795 - val_accuracy: 0.6250
# Epoch 5/150
# 17/17 [==============================] - 0s 10ms/step - loss: 7.6697 - accuracy: 0.5130 - val_loss: 7.6795 - val_accuracy: 0.6250
# Epoch 6/150
# 17/17 [==============================] - 0s 11ms/step - loss: 7.6697 - accuracy: 0.5130 - val_loss: 7.6795 - val_accuracy: 0.6250
# Epoch 7/150
# ...
