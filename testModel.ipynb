# %%
import cv2
import tensorflow as tf
from tensorflow import keras
import os
import pickle

# %%
#CATEGORIES = ["CT_COVID", "CT_NonCOVID"]
cat = ["testing_covid_19","testing_noncovid_19"]
dir = "/Users/aisha/virtualenv/"


model = tf.keras.models.load_model("my-CNN.model")
main_arr = []

# %%
testingx = pickle.load(open("testingx.pickle","rb"))
testingy = pickle.load(open("testingy.pickle","rb"))
tesingx = testingx/225.0

# %%
for m in testingx:

    #print(testingx)
    prediction = model.predict(testingx)
    #print(prediction)  # will be a list in a list.
    print(cat[int(prediction[0][0])])
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7fa4581e8440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7fa4581e8440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# testing_covid_19
# testing_covid_19
# testing_covid_19
# ...
